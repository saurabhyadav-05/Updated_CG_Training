# %% [markdown]
# Project Scenario 2: AI Research Assistant for Students
# A university wants to build an AI-powered Research Assistant that can help students quickly understand long academic articles and generate structured insights.
#
# The system should be able to:
#
# Summarize long text
#
#
# Extract key insights
#
#
# Answer questions about the content
#
#
# Generate concise explanations
#
#
# You are required to design and implement a prototype using a Large Language Model (LLM).
#
# Task 1 – LLM Interaction Setup (5 Marks)
# Use any LLM API such as:
#
# Gemini
#
#
# OpenAI
#
#
# HuggingFace Transformers
#
#
# Steps:
#
# Write Python code to send a text prompt to an LLM.
#
#
# Provide a sample long article or research paragraph.
#
#
# Generate a summary using the LLM.
#
#
# Deliverable:
#
# Python code
#
#
# Input text sample
#
#
# Generated output
#
#
# Task 2 – Prompt Engineering Experiments (8 Marks)
# Design and test three different prompting strategies.
#
# 1️⃣ Zero-Shot Prompt
# Ask the model to summarize the article without providing examples.
#
# Example task:
#
# Summarize the following article in 5 bullet points.
#
# 2️⃣ Few-Shot Prompt
# Provide 2 example summaries before asking the model to summarize a new article.
#
# 3️⃣ Chain-of-Thought Prompt
# Ask the model to reason step-by-step before generating the summary.
#
# Example structure:
#
# Analyze the article step by step:
#
# 1. Identify the main topic
#
# 2. Extract key ideas
#
# 3. Generate a concise summary
#
# Deliverable:
#
# All three prompts
#
#
# Model outputs
#
#
# Comparison of responses
#
#
# Task 3 – Prompt Optimization (7 Marks)
# Improve the prompt so that the AI generates better executive summaries.
#
# Your optimized prompt must produce:
#
# 3 key insights
#
#
# 1 actionable takeaway
#
#
# Professional tone
#
#
# Test the optimized prompt on two different articles.
#
# Deliverable:
#
# Final optimized prompt
#
#
# Two example outputs
#
#
# Task 4 – Tokenization Experiment (5 Marks)
# Use a tokenizer from HuggingFace or any LLM library.
#
# Steps:
#
# Tokenize a paragraph of text.
#
#
# Count the total number of tokens.
#
#
# Display the tokenized output.
#
#
# Example tools:
#
# tiktoken
#
#
# transformers tokenizer
#
#
# Deliverable:
#
# Python code
#
#
# Token count
#
#
# Example tokenized output
#
#
# Task 5 – Build a Mini AI Tool (5 Marks)
# Create a simple AI assistant that takes a long article and produces:
#
# A short summary
#
#
# Key insights
#
#
# One actionable recommendation
#
#
# The program should:
#
# Accept text input
#
#
# Send prompt to LLM
#
#
# Display structured output
#
#
# Deliverable:
#
# Python script or notebook
#
#
# Example result

# %%
from transformers import pipeline, AutoTokenizer

# Task 1 – LLM Interaction Setup


print("\nLoading AI Model... Please wait\n")

generator = pipeline("text-generation", model="gpt2")

print("Model Loaded Successfully!\n")

# Sample Research Article
article = """
Artificial Intelligence (AI) has become one of the most transformative technologies of the 21st century. 
It is widely used in industries such as healthcare, finance, education, and manufacturing. 
Machine learning, a subset of AI, allows computers to learn from data and improve performance without explicit programming.

Recent advances in deep learning have significantly improved capabilities in image recognition, natural language processing, 
and autonomous systems. For example, AI-powered diagnostic tools can detect diseases from medical images with high accuracy.

Despite its benefits, AI also presents challenges such as data privacy concerns, ethical issues, and job displacement. 
Researchers are working to create responsible AI systems that are transparent, fair, and accountable.

In the future, AI is expected to assist humans in solving complex global problems such as climate change, 
healthcare accessibility, and smart city development.
"""

print("TASK 1: ARTICLE SUMMARY")

prompt = f"Summarize the following article:\n\n{article}\n\nSummary:"

response = generator(prompt, max_length=200)

print(response[0]['generated_text'])

# Task 2 – Prompt Engineering Experiments

print(" TASK 2: ZERO-SHOT PROMPT ")

zero_shot_prompt = f"""
Summarize the following article in 5 bullet points.

Article:
{article}
"""

response = generator(zero_shot_prompt, max_length=200)

print(response[0]['generated_text'])


print("TASK 2: FEW-SHOT PROMPT ")

few_shot_prompt = f"""
Example 1
Article: Climate change is affecting global temperatures and weather patterns.
Summary:
• Global temperatures are rising
• Climate change affects weather patterns
• Reducing emissions is necessary

Example 2
Article: Online education allows students to learn remotely using digital platforms.
Summary:
• Online learning enables remote education
• Digital platforms increase accessibility
• Technology improves learning flexibility

Now summarize the following article.

Article:
{article}

Summary:
"""

response = generator(few_shot_prompt, max_length=250)

print(response[0]['generated_text'])


print("TASK 2: CHAIN OF THOUGHT PROMPT ")

cot_prompt = f"""
Analyze the article step by step.

Step 1: Identify the main topic
Step 2: Extract key ideas
Step 3: Generate a concise summary

Article:
{article}

Answer:
"""

response = generator(cot_prompt, max_length=250)

print(response[0]['generated_text'])

# Task 3 – Prompt Optimization


print(" TASK 3: OPTIMIZED PROMPT")

optimized_prompt = f"""
You are an academic research assistant.

Analyze the following article and produce:

1. Executive Summary
2. Three Key Insights
3. One Actionable Takeaway

Use a professional tone.

Article:
{article}

Response Format:

Executive Summary:
Key Insights:
Actionable Takeaway:
"""

response = generator(optimized_prompt, max_length=250)

print(response[0]['generated_text'])

# Test optimized prompt on second article

article2 = """
Blockchain technology is a decentralized digital ledger used to record transactions securely.
It removes the need for intermediaries and ensures transparency and trust in digital systems.
Blockchain is widely used in cryptocurrencies, supply chain management, and digital identity verification.
"""

print("TASK 3: TEST ON SECOND ARTICLE ")

test_prompt = optimized_prompt.replace(article, article2)

response = generator(test_prompt, max_length=200)

print(response[0]['generated_text'])

# Task 4 – Tokenization Experiment


print(" TASK 4: TOKENIZATION EXPERIMENT ")

tokenizer = AutoTokenizer.from_pretrained("gpt2")

paragraph = """
Artificial Intelligence enables machines to perform tasks that normally require human intelligence.
"""

tokens = tokenizer.tokenize(paragraph)
token_ids = tokenizer.encode(paragraph)

print("Tokens:\n")
print(tokens)

print("\nToken IDs:\n")
print(token_ids)

print("\nTotal Number of Tokens:", len(token_ids))

# Task 5 – Mini AI Research Assistant Tool

print("TASK 5: MINI AI RESEARCH ASSISTANT")

def research_assistant(text):

    prompt = f"""
    You are an AI research assistant.

    From the following article generate:

    1. Short Summary
    2. Three Key Insights
    3. One Actionable Recommendation

    Article:
    {text}

    Response:
    """

    result = generator(prompt, max_length=250)

    return result[0]['generated_text']


# Accept user input
user_article = input("\nPaste a research article here:\n")

output = research_assistant(user_article)

print("AI ASSISTANT OUTPUT ")
print(output)
# Out:
# Loading AI Model... Please wait
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Model Loaded Successfully!
#
# TASK 1: ARTICLE SUMMARY
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Summarize the following article:
#
#
# Artificial Intelligence (AI) has become one of the most transformative technologies of the 21st century.
# It is widely used in industries such as healthcare, finance, education, and manufacturing.
# Machine learning, a subset of AI, allows computers to learn from data and improve performance without explicit programming.
#
# Recent advances in deep learning have significantly improved capabilities in image recognition, natural language processing,
# and autonomous systems. For example, AI-powered diagnostic tools can detect diseases from medical images with high accuracy.
#
# Despite its benefits, AI also presents challenges such as data privacy concerns, ethical issues, and job displacement.
# Researchers are working to create responsible AI systems that are transparent, fair, and accountable.
#
# In the future, AI is expected to assist humans in solving complex global problems such as climate change,
# healthcare accessibility, and smart city development.
#
#
# Summary:
#
# AI is the ability to create, interpret, and understand information and to solve complex problems. It is used in the field of medicine, medicine research, and medicine education.
#
# In the United States alone, 1.8 million jobs are at risk of AI-related death due to human error.
#
# For more information, see the "What's New in AI" article by R. D. V. Narayanan, Ph.D.
#
# About The Author:
#
# I am a PhD student in Artificial Intelligence in the Department of Computer Science and Engineering at Stanford University. I have taught at MIT since 2003 and at the University of Massachusetts, Amherst since 2004. I am currently working on a book in the field of human intelligence, with the goal of exploring the possibility of designing AI as a way to create and understand knowledge-based, knowledge-based systems.
#
# The author is a postdoctoral researcher at the University of California, Davis, and a member of the Stanford Artificial Intelligence Lab.
#
# Related Links:
#
# http://www.freedesktop.org/wiki/Prof_R_D_V_Narayanan
#
# http://www.freedesktop.org/wiki/Prof_
#  TASK 2: ZERO-SHOT PROMPT
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=250) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Summarize the following article in 5 bullet points.
#
# Article:
#
# Artificial Intelligence (AI) has become one of the most transformative technologies of the 21st century.
# It is widely used in industries such as healthcare, finance, education, and manufacturing.
# Machine learning, a subset of AI, allows computers to learn from data and improve performance without explicit programming.
#
# Recent advances in deep learning have significantly improved capabilities in image recognition, natural language processing,
# and autonomous systems. For example, AI-powered diagnostic tools can detect diseases from medical images with high accuracy.
#
# Despite its benefits, AI also presents challenges such as data privacy concerns, ethical issues, and job displacement.
# Researchers are working to create responsible AI systems that are transparent, fair, and accountable.
#
# In the future, AI is expected to assist humans in solving complex global problems such as climate change,
# healthcare accessibility, and smart city development.
#
#
# Artificial Intelligence (AI) has become one of the most transformative technologies of the 21st century.
#
# It is widely used in industries such as healthcare, finance, education, and manufacturing.
#
# Machine learning, a subset of AI, allows computers to learn from data and improve performance without explicit programming. Recent advances in deep learning have significantly improved capabilities in image recognition, natural language processing,
#
# and autonomous systems. For example, AI-powered diagnostic tools can detect diseases from medical images with high accuracy. Despite its benefits, AI also presents challenges such as data privacy concerns, ethical issues, and job displacement.
#
# Researchers are working to create responsible AI systems that are transparent, fair, and accountable.
#
# In the future, AI is expected to assist humans in solving complex global problems such as climate change, health care accessibility, and smart city development.
#
# In the future, AI is expected to assist humans in solving complex global problems such as climate change, health care accessibility, and smart city development.
#
# Researchers are working to create responsible AI systems that are transparent, fair, and accountable.
#
# In the future, AI is expected to assist humans in solving complex global problems such as climate change, health care
# TASK 2: FEW-SHOT PROMPT
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=250) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Example 1
# Article: Climate change is affecting global temperatures and weather patterns.
# Summary:
# • Global temperatures are rising
# • Climate change affects weather patterns
# • Reducing emissions is necessary
#
# Example 2
# Article: Online education allows students to learn remotely using digital platforms.
# Summary:
# • Online learning enables remote education
# • Digital platforms increase accessibility
# • Technology improves learning flexibility
#
# Now summarize the following article.
#
# Article:
#
# Artificial Intelligence (AI) has become one of the most transformative technologies of the 21st century.
# It is widely used in industries such as healthcare, finance, education, and manufacturing.
# Machine learning, a subset of AI, allows computers to learn from data and improve performance without explicit programming.
#
# Recent advances in deep learning have significantly improved capabilities in image recognition, natural language processing,
# and autonomous systems. For example, AI-powered diagnostic tools can detect diseases from medical images with high accuracy.
#
# Despite its benefits, AI also presents challenges such as data privacy concerns, ethical issues, and job displacement.
# Researchers are working to create responsible AI systems that are transparent, fair, and accountable.
#
# In the future, AI is expected to assist humans in solving complex global problems such as climate change,
# healthcare accessibility, and smart city development.
#
#
# Summary:
#  become a powerful tool for improving the lives of many people.
#
# In the meantime, we must ensure that the world's children need the best education possible.
#
# What is a good teacher?
#
# A good teacher is one who is able to help children understand and understand their world.
#
# This is especially important because even in our most developed nations, children are often not taught the basics of a particular subject.
#
# What is a good teacher?
#
# A good teacher places a high priority on developing children's abilities, skills, and skills by providing a positive environment for learning.
#
# This includes:
#
# • the use of good-quality information and critical thinking skills
#
# • proper communication and non-judgmental social interactions
#
# • the development of students' personal and professional perspectives
#
# • the development of skills and social skills
#
# • the development of a strong social learning environment
#
# • the ability to create a new life environment
#
# • the ability to address the needs of students and their families
#
# • the ability to communicate and use language correctly
#
# • the ability to develop self-confidence and personal relationships
#
# • the ability to communicate and communicate effectively
#
# • the ability to develop the ability to engage
# TASK 2: CHAIN OF THOUGHT PROMPT
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=250) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Analyze the article step by step.
#
# Step 1: Identify the main topic
# Step 2: Extract key ideas
# Step 3: Generate a concise summary
#
# Article:
#
# Artificial Intelligence (AI) has become one of the most transformative technologies of the 21st century.
# It is widely used in industries such as healthcare, finance, education, and manufacturing.
# Machine learning, a subset of AI, allows computers to learn from data and improve performance without explicit programming.
#
# Recent advances in deep learning have significantly improved capabilities in image recognition, natural language processing,
# and autonomous systems. For example, AI-powered diagnostic tools can detect diseases from medical images with high accuracy.
#
# Despite its benefits, AI also presents challenges such as data privacy concerns, ethical issues, and job displacement.
# Researchers are working to create responsible AI systems that are transparent, fair, and accountable.
#
# In the future, AI is expected to assist humans in solving complex global problems such as climate change,
# healthcare accessibility, and smart city development.
#
#
# Answer:
#
# AI has changed the face of many industries. It is now possible to identify, manage, and eliminate problems that are not at the top of the list of the top-performing industries.
#
# AI is advancing many applications beyond science and technology, which are now being rapidly applied in the fields of healthcare, education, and manufacturing.
#
# One of the benefits of AI is that it is able to help humans in many areas, regardless of the technology.
#
# It has made the use of AI, in particular in the healthcare field, as more and more companies are developing innovative ways to leverage AI to improve their systems.
#
# AI has also created a new wave of applications that are helping to drive productivity.
#
# The next frontier of AI is artificial intelligence, which is becoming more sophisticated, faster and more efficient.
#
# AI is building a new era of new business models that will revolutionize the way we analyze, manage, and provide information.
#
# This is the future of AI.
#
# It is still very much under development, but it is rapidly becoming a reality.
#
# In the future, AI will help us make smarter decisions, improve the quality of our lives, and improve the quality of our work.
#
# In order
#  TASK 3: OPTIMIZED PROMPT
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# You are an academic research assistant.
#
# Analyze the following article and produce:
#
# 1. Executive Summary
# 2. Three Key Insights
# 3. One Actionable Takeaway
#
# Use a professional tone.
#
# Article:
#
# Artificial Intelligence (AI) has become one of the most transformative technologies of the 21st century.
# It is widely used in industries such as healthcare, finance, education, and manufacturing.
# Machine learning, a subset of AI, allows computers to learn from data and improve performance without explicit programming.
#
# Recent advances in deep learning have significantly improved capabilities in image recognition, natural language processing,
# and autonomous systems. For example, AI-powered diagnostic tools can detect diseases from medical images with high accuracy.
#
# Despite its benefits, AI also presents challenges such as data privacy concerns, ethical issues, and job displacement.
# Researchers are working to create responsible AI systems that are transparent, fair, and accountable.
#
# In the future, AI is expected to assist humans in solving complex global problems such as climate change,
# healthcare accessibility, and smart city development.
#
#
# Response Format:
#
# Executive Summary:
# Key Insights:
# Actionable Takeaway:
#  Takeaways:
#
# What are the benefits and drawbacks of AI?
#
# How do we find the right technologies?
#
# Are we ready for the next big AI revolution?
#
# Is our current technology ready for a future where we have massive opportunities to use it for the next big thing?
#
# How is AI coming together?
#
# What is the future of AI?
#
# What is the future of AI?
#
# The implications of AI for society
#
# How important is the future of AI for humanity?
#
# What should we do about AI?
#
# How can we create more intelligent machines?
#
# A study published in a journal, New Scientist, in 2012, showed that while the human brain takes over a quarter of the world's computing power, the next generation of AI will have a much smaller share, with one-third of the world's computing power being done by the next generation of AI.
#
# The future of Artificial Intelligence is not in the human-controlled world, but in the robotics world where robots are being built in factories and other industrial environments. The future of artificial intelligence is in the future of human and robotic interactions.
#
# A new paper published in the journal, Artificial Intelligence and the Future of Human Consciousness
# TASK 3: TEST ON SECOND ARTICLE
#
# You are an academic research assistant.
#
# Analyze the following article and produce:
#
# 1. Executive Summary
# 2. Three Key Insights
# 3. One Actionable Takeaway
#
# Use a professional tone.
#
# Article:
#
# Blockchain technology is a decentralized digital ledger used to record transactions securely.
# It removes the need for intermediaries and ensures transparency and trust in digital systems.
# Blockchain is widely used in cryptocurrencies, supply chain management, and digital identity verification.
#
#
# Response Format:
#
# Executive Summary:
# Key Insights:
# Actionable Takeaway:
#
# As the Internet is constantly being altered and change has come in, the future of the Internet is changing very rapidly.
#
# We are living in a time when there are several ways to store and access information. There are myriad ways to use social media, and the Internet is a highly connected and connected environment.
#
# We are seeing a surge in the use of social media applications such as Instagram and Vine. There is a high demand for this type of content, and many companies are looking for innovative ways to monetize and monetize.
#
# There are many innovative ways to use social media in business and organizations.
#
# The potential for social media to be used to increase value for everyone is significant.
#
# Our research shows that while there are many ways to monetize and monetize social media, there is also a plethora of ways to monetize and monetize other kinds of social media.
#
# The need for this type of content is growing exponentially.
#
# A successful digital advertising business will have a strong presence in the digital space.
#
# What we found is that the use of social media can be extremely effective for business as well as for other types of advertising.
#
# What we found is that the use of social media can be extremely effective for
#  TASK 4: TOKENIZATION EXPERIMENT
# Tokens:
#
# ['Ċ', 'Art', 'ificial', 'ĠIntelligence', 'Ġenables', 'Ġmachines', 'Ġto', 'Ġperform', 'Ġtasks', 'Ġthat', 'Ġnormally', 'Ġrequire', 'Ġhuman', 'Ġintelligence', '.', 'Ċ']
#
# Token IDs:
#
# [198, 8001, 9542, 9345, 13536, 8217, 284, 1620, 8861, 326, 7685, 2421, 1692, 4430, 13, 198]
#
# Total Number of Tokens: 16
# TASK 5: MINI AI RESEARCH ASSISTANT
